# %% [markdown]
# Q1

# %%
while True:
  print("\nMenu option")
  print("1.generate a pattern")
  print("2.anlyze a range of number")
  print("3.Exit")
  choice = input("Enter your choice:")
  if choice == "1":
    row = int(input("Enter the number of rows:"))

    if row > 0:
      for i in range(1, row +1):
       print("*" * i)
    else:
      print("Invalid number of rows")

  elif choice == "2":

        start = int(input("Enter the starting number:"))
        end = int(input("Enter the ending number:"))

        if start > end:
          print("Invalid range")
        else:
          odd_number = [num for num in range(start, end + 1) if num % 2 != 0]
          even_number = [num for num in range(start, end + 1) if num % 2 == 0]
          total_number = sum(range(start,end +1))

          print("odd_number",odd_number)
          print("even_number",even_number)
          print("total_number",total_number)

  elif choice == "3":
    print("Exiting the program. goodbye!")
    break
  else:
    print("Invalid choice")
# Out:
# Menu option
# 1.generate a pattern
# 2.anlyze a range of number
# 3.Exit
# Enter your choice:2
# Enter the starting number:10
# Enter the ending number:20
# odd_number [11, 13, 15, 17, 19]
# even_number [10, 12, 14, 16, 18, 20]
# total_number 165
#
# Menu option
# 1.generate a pattern
# 2.anlyze a range of number
# 3.Exit
# Enter your choice:1
# Enter the number of rows:9
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
#
# Menu option
# 1.generate a pattern
# 2.anlyze a range of number
# 3.Exit
# Enter your choice:3
# Exiting the program. goodbye!
